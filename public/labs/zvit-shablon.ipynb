# %% [markdown]
# # Лабораторна робота № _ · _назва_
#
# **Курс:** Машинне навчання у ройових системах БПЛА · КПІ ім. Ігоря Сікорського
#
# | Учасник | ПІБ, група | За що відповідав | Комірки |
# |---|---|---|---|
# | A |  |  |  |
# | B |  |  |  |
# | C |  |  |  |
#
# > Ноутбук має виконуватися **від початку до кінця без ручних правок**:
# > `Kernel → Restart & Run All` не повинен давати помилок.
# > Перед здачею перевірте це на чистому ядрі.

# %% [markdown]
# ## Мета
#
# _Перепишіть мету з методичних вказівок і додайте одне речення про те, що саме робила ваша бригада._

# %% [markdown]
# ## Вихідні дані
#
# _Числові параметри роботи: маса апарата, частоти, тривалість епізоду, коефіцієнти._

# %%
import numpy as np
import matplotlib.pyplot as plt

# Зерно фіксуємо явно: без цього результат не відтворюється,
# а чек-лист відтворюваності вимагає саме списку зерен.
SEED = 0
rng = np.random.default_rng(SEED)

# %% [markdown]
# ## Хід виконання
#
# _Кожен крок «Порядку виконання» — окремий підрозділ. Код того учасника, який
# за цей крок відповідає, лишається у своїх комірках._

# %% [markdown]
# ### [A] _крок 1_

# %%
# TODO: код учасника A

# %% [markdown]
# ### [B] _крок 2_

# %%
# TODO: код учасника B

# %% [markdown]
# ### [C] _крок 3_

# %%
# TODO: код учасника C

# %% [markdown]
# ## Результати
#
# _Таблиці й рисунки, а не переказ. Кожен рисунок згадується в тексті поруч._

# %%
# TODO: підсумкова таблиця й графіки

# %% [markdown]
# ## Аналіз
#
# _Поясніть, **чому** вийшло саме так. Це головний розділ: таблицю з числами
# може зробити кожен, а пояснення різниці — ні. Якщо результат розійшовся
# з очікуваним, напишіть про це чесно й висуньте припущення про причину._

# %% [markdown]
# ## Чек-лист відтворюваності
#
# Заповніть, це частина оцінки.
#
# - [ ] середовище та його версія:
# - [ ] зерна генератора:
# - [ ] кількість незалежних запусків (не менше п'яти):
# - [ ] повна таблиця гіперпараметрів наведена нижче
# - [ ] однаковий бюджет пошуку для всіх порівнюваних
# - [ ] протокол оцінювання описано
# - [ ] на графіку вказано, що є лінією і що затіненням
# - [ ] базову лінію для порівняння наведено
# - [ ] обчислювальні витрати вказано:

# %%
import sys, platform
print('Python  ', sys.version.split()[0])
print('платформа', platform.platform())
print('numpy   ', np.__version__)
print('зерно   ', SEED)

# %% [markdown]
# ## Висновки
#
# Три-п'ять пунктів. Кожен — перевірюване твердження **з числом**,
# а не «ознайомилися з роботою симулятора».
#
# 1.
# 2.
# 3.
